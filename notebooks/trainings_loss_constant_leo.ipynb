# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import MaxNLocator
import numpy as np
import matplotlib.ticker as ticker
import json
import os

# %%
DATASET = "JETCLASS"
SCHEDULER = "const"
N_JETS = 600000

#modify name for specific traings run
base = "/hpcwork/rwth0934/hep_foundation_model/training"
folder = f"{base}/{DATASET}_{N_JETS}_{SCHEDULER}_leo"

CLASSES = ["QCD", "TTBar"]

for CLASS in CLASSES:


    config_path = os.path.join(folder, f"{CLASS}_config.json")

    with open(config_path, "r") as f:
        config = json.load(f)

    important_keys = [
        "n_jets",
        "n_jets_val",
        "lr",
        "batch_size",
        "dropout",
        "weight_decay",
        "scheduler",
        "restart_period",
    ]

    param_text = "\n".join([f"{k}: {config[k]}" for k in important_keys if k in config])

    EPOCH_STEPS = N_JETS / config["batch_size"]

    fig, (ax_plot, ax_text) = plt.subplots(
        1, 2,
        figsize=(12, 5),
        gridspec_kw={"width_ratios": [3, 1]}
    )

    data = pd.read_csv(f"{folder}/{CLASS}_training_log.csv")

    data["epoch"] = data["step"] / EPOCH_STEPS
    data_min = np.argmin(data["val_loss"])


    # ---- Loss plot ---
    ax_plot.scatter(data["epoch"], data["train_loss"], label="train loss",
           color = "red",
           marker = "^")
    ax_plot.scatter(data["epoch"], data["val_loss"], label=f"val loss \n min = {data_min}",
            color = "red",
            marker = "s")

    ax_plot.plot(data["epoch"], data["train_loss"],
            color = "red",
            linewidth = 0.5,
            alpha = 0.5)
    ax_plot.plot(data["epoch"], data["val_loss"],
            color = "red",
            linewidth = 0.5,
            alpha = 0.5)


    ax_plot.set_xlabel("Epoch")
    ax_plot.set_ylabel("Loss")
    ax_plot.legend()

    # ---- Text panel ----
    ax_text.axis("off")  # remove axes

    ax_text.text(
        0, 1,
        param_text,
        fontsize=10,
        va="top",
        family="monospace"
    )

    ax_plot.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

    #ax.set_yscale("log")
    ax_plot.set_title(f"Training/Validation Loss {CLASS}")


    plt.tight_layout()
    plt.show()


fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(qcd["epoch"], qcd["lr"], color = "blue", alpha = 0.5)
ax.scatter(qcd["epoch"], qcd["lr"], color = "blue", alpha = 0.5)

ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

ax.set_xlabel("step")
ax.set_ylabel("Learning rate")

ax.set_title("Learning rate")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 91
#      86     plt.show()
#      89 fig, ax = plt.subplots(figsize=(10, 5))
# ---> 91 ax.plot(qcd["epoch"], qcd["lr"], color = "blue", alpha = 0.5)
#      92 ax.scatter(qcd["epoch"], qcd["lr"], color = "blue", alpha = 0.5)
#      94 ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
#
# NameError: name 'qcd' is not defined

# %%
DATASET = "JETCLASS"
SCHEDULER = "cosine_restarts"
N_JETS = 600000

#modify name for specific traings run
base = "/hpcwork/rwth0934/hep_foundation_model/training"
folder = f"{base}/{DATASET}_{N_JETS}_{SCHEDULER}_orig"

CLASSES = ["QCD", "TTBar"]

for CLASS in CLASSES:


    config_path = os.path.join(folder, f"{CLASS}_config.json")

    with open(config_path, "r") as f:
        config = json.load(f)

    important_keys = [
        "n_jets",
        "n_jets_val",
        "lr",
        "batch_size",
        "dropout",
        "weight_decay",
        "scheduler",
        "restart_period",
    ]

    param_text = "\n".join([f"{k}: {config[k]}" for k in important_keys if k in config])

    EPOCH_STEPS = N_JETS / config["batch_size"]

    fig, (ax_plot, ax_text) = plt.subplots(
        1, 2,
        figsize=(12, 5),
        gridspec_kw={"width_ratios": [3, 1]}
    )

    data = pd.read_csv(f"{folder}/{CLASS}_training_log.csv")

    data["epoch"] = data["step"] / EPOCH_STEPS
    data_min = np.argmin(data["val_loss"])


    # ---- Loss plot ---
    ax_plot.scatter(data["epoch"], data["train_loss"], label="train loss",
           color = "red",
           marker = "^")
    ax_plot.scatter(data["epoch"], data["val_loss"], label=f"val loss \n min = {data_min}",
            color = "red",
            marker = "s")

    ax_plot.plot(data["epoch"], data["train_loss"],
            color = "red",
            linewidth = 0.5,
            alpha = 0.5)
    ax_plot.plot(data["epoch"], data["val_loss"],
            color = "red",
            linewidth = 0.5,
            alpha = 0.5)


    ax_plot.set_xlabel("Epoch")
    ax_plot.set_ylabel("Loss")
    ax_plot.legend()

    # ---- Text panel ----
    ax_text.axis("off")  # remove axes

    ax_text.text(
        0, 1,
        param_text,
        fontsize=10,
        va="top",
        family="monospace"
    )

    ax_plot.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

    #ax.set_yscale("log")
    ax_plot.set_title(f"Training/Validation Loss {CLASS}")


    plt.tight_layout()
    plt.show()


fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(qcd["epoch"], qcd["lr"], color = "blue", alpha = 0.5)
ax.scatter(qcd["epoch"], qcd["lr"], color = "blue", alpha = 0.5)

ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

ax.set_xlabel("step")
ax.set_ylabel("Learning rate")

ax.set_title("Learning rate")

plt.show()
# Out:
# Text(0.5, 1.0, 'batch loss qcd with constant scheduler batchsize 100')
